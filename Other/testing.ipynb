# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

import matplotlib.pyplot as plt
from matplotlib import font_manager

from timple.timedelta import strftimedelta


import fastf1 as f1
import fastf1.plotting
from fastf1.core import Laps

# %%
teams = ["Ferrari", "Red Bull Racing", "Mercedes", "McLaren", "RB", "Aston Martin", "Kick Sauber", "Haas F1 Team", "Williams", "Alpine"]

team_colours = {
    "Ferrari": "#DC0000", 
    "Red Bull Racing": "#3671C6",
    "Mercedes": "#27F4D2",
    "McLaren": "#FF8000",
    "RB": "#3671C6",
    "Aston Martin": "#229971", 
    "Kick Sauber": "#52D252",
    "Haas F1 Team": "#B6BABD",
    "Williams": "#64C4FF",
    "Alpine": "#FF87BC"
}

tyre_colours = {
    "soft": "#E30E23",
    "medium": "#F2CA1F",
    "hard": "#E7E5E3",
    "inters": "#07A53C",
    "wets": "#3C65AB"
}

# %%
font_files = font_manager.findSystemFonts(fontpaths=None, fontext="ttf")

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

font_manager.get_font_names()

fastf1.plotting.setup_mpl(mpl_timedelta_support=True, color_scheme='fastf1', misc_mpl_mods=True)

# %%
day1 = f1.get_testing_session(year=2024,session_number=1, test_number=1)
day2 = f1.get_testing_session(year=2024,session_number=2, test_number=1)
day3 = f1.get_testing_session(year=2024,session_number=3, test_number=1)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (1.4 GB) C:\Users\maxvo\AppData\Local\Temp\fastf1

# %%
day1.load()
day2.load()
day3.load()
# Out:
# core           INFO 	Loading data for Pre-Season Testing - Practice 1 [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 44
# core        WARNING 	Driver  1: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  3: Lap timing integrity check failed for 2 lap(s)
# core        WARNING 	Driver  4: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 10: Lap timing integrity check failed for 2 lap(s)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 11)
# core        WARNING 	Driver 18: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 24: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 44)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Pre-Season Testing - Practice 2 [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 1
# core        WARNING 	No lap data for driver 23
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 1)
# core        WARNING 	Driver 11: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 23)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# core           INFO 	Loading data for Pre-Season Testing - Practice 3 [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 2
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 2)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']

# %%
day2.results
# Out:
#    DriverNumber BroadcastName Abbreviation DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER           Red Bull Racing
# 2             2    L SARGEANT          SAR                  Williams
# 3             3   D RICCIARDO          RIC                        RB
# 4             4      L NORRIS          NOR                   McLaren
# 10           10       P GASLY          GAS                    Alpine
# 11           11       S PEREZ          PER           Red Bull Racing
# 14           14      F ALONSO          ALO              Aston Martin
# 16           16     C LECLERC          LEC                   Ferrari
# 18           18      L STROLL          STR              Aston Martin
# 20           20   K MAGNUSSEN          MAG              Haas F1 Team
# 22           22     Y TSUNODA          TSU                        RB
# 23           23       A ALBON          ALB                  Williams
# 24           24        G ZHOU          ZHO               Kick Sauber
# 27           27  N HULKENBERG          HUL              Haas F1 Team
# 31           31        E OCON          OCO                    Alpine
# 44           44    L HAMILTON          HAM                  Mercedes
# 55           55       C SAINZ          SAI                   Ferrari
# 63           63     G RUSSELL          RUS                  Mercedes
# 77           77      V BOTTAS          BOT               Kick Sauber
# 81           81     O PIASTRI          PIA                   McLaren
#
#    TeamColor TeamId  FirstName    LastName          FullName  ... CountryCode  \
# 1     3671c6               Max  Verstappen    Max Verstappen  ...         NED
# 2     64c4ff             Logan    Sargeant    Logan Sargeant  ...         USA
# 3     6692ff            Daniel   Ricciardo  Daniel Ricciardo  ...         AUS
# 4     ff8000             Lando      Norris      Lando Norris  ...         GBR
# 10    ff87bc            Pierre       Gasly      Pierre Gasly  ...         FRA
# 11    3671c6            Sergio       Perez      Sergio Perez  ...         MEX
# 14    229971          Fernando      Alonso   Fernando Alonso  ...         ESP
# 16    e8002d           Charles     Leclerc   Charles Leclerc  ...         MON
# 18    229971             Lance      Stroll      Lance Stroll  ...         CAN
# 20    b6babd             Kevin   Magnussen   Kevin Magnussen  ...         DEN
# 22    6692ff              Yuki     Tsunoda      Yuki Tsunoda  ...         JPN
# 23    64c4ff         Alexander       Albon   Alexander Albon  ...         THA
# 24    52e252            Guanyu        Zhou       Guanyu Zhou  ...         CHN
# 27    b6babd              Nico  Hulkenberg   Nico Hulkenberg  ...         GER
# 31    ff87bc           Esteban        Ocon      Esteban Ocon  ...         FRA
# 44    27f4d2             Lewis    Hamilton    Lewis Hamilton  ...         GBR
# 55    e8002d            Carlos       Sainz      Carlos Sainz  ...         ESP
# 63    27f4d2            George     Russell    George Russell  ...         GBR
# 77    52e252          Valtteri      Bottas   Valtteri Bottas  ...         FIN
# 81    ff8000             Oscar     Piastri     Oscar Piastri  ...         AUS
#
#    Position  ClassifiedPosition GridPosition  Q1  Q2  Q3 Time Status Points
# 1       NaN                              NaN NaT NaT NaT  NaT           NaN
# 2       NaN                              NaN NaT NaT NaT  NaT           NaN
# 3       NaN                              NaN NaT NaT NaT  NaT           NaN
# 4       NaN                              NaN NaT NaT NaT  NaT           NaN
# 10      NaN                              NaN NaT NaT NaT  NaT           NaN
# 11      NaN                              NaN NaT NaT NaT  NaT           NaN
# 14      NaN                              NaN NaT NaT NaT  NaT           NaN
# 16      NaN                              NaN NaT NaT NaT  NaT           NaN
# 18      NaN                              NaN NaT NaT NaT  NaT           NaN
# 20      NaN                              NaN NaT NaT NaT  NaT           NaN
# 22      NaN                              NaN NaT NaT NaT  NaT           NaN
# 23      NaN                              NaN NaT NaT NaT  NaT           NaN
# 24      NaN                              NaN NaT NaT NaT  NaT           NaN
# 27      NaN                              NaN NaT NaT NaT  NaT           NaN
# 31      NaN                              NaN NaT NaT NaT  NaT           NaN
# 44      NaN                              NaN NaT NaT NaT  NaT           NaN
# 55      NaN                              NaN NaT NaT NaT  NaT           NaN
# 63      NaN                              NaN NaT NaT NaT  NaT           NaN
# 77      NaN                              NaN NaT NaT NaT  NaT           NaN
# 81      NaN                              NaN NaT NaT NaT  NaT           NaN
#
# [20 rows x 21 columns]

# %%
day1_laps = day1.laps
day1_laps = day1_laps.dropna(subset="LapTime")

day2_laps = day2.laps
day2_laps = day2_laps.dropna(subset="LapTime")

day3_laps = day3.laps
day3_laps = day3_laps.dropna(subset="LapTime")

days = [day1_laps, day2_laps, day3_laps]

# %%
fastest_lap_day1 = day1.laps.pick_fastest()
fastest_lap_day2 = day2_laps.pick_fastest()

# %%
drivers_day1 = pd.unique(day1.laps['Driver'])

list_fastest_laps_day1 = list()
for drv in drivers_day1:
    drvs_fastest_lap = day1.laps.pick_driver(drv).pick_fastest()
    list_fastest_laps_day1.append(drvs_fastest_lap)
fastest_laps_day1 = Laps(list_fastest_laps_day1).sort_values(by="LapTime").reset_index(drop=True)




drivers_day2 = pd.unique(day2.laps["Driver"])

list_fastest_laps_day2 = list()
for drv in drivers_day2:
    drvs_fastest_lap = day2_laps.pick_driver(drv).pick_fastest()
    list_fastest_laps_day2.append(drvs_fastest_lap)
fastest_laps_day2 = Laps(list_fastest_laps_day2).sort_values(by="LapTime").reset_index(drop=True)

# %%
team_colours_day1 = list()
for index, lap in fastest_laps_day1.iterlaps():
    for key, value in team_colours.items():
        if key == lap["Team"]:
            colour = value
    team_colours_day1.append(colour.lower())


team_colours_day2 = list()
for index, lap in fastest_laps_day2.iterlaps():
    for key, value in team_colours.items():
        if key == lap["Team"]:
            colour = value
    team_colours_day2.append(colour.lower())

# %%
fastest_laps_day1
# Out:
#                      Time Driver DriverNumber                LapTime  \
# 0  0 days 08:38:20.431000    VER            1 0 days 00:01:31.344000
# 1  0 days 06:50:42.426000    NOR            4 0 days 00:01:32.484000
# 2  0 days 06:30:12.955000    SAI           55 0 days 00:01:32.584000
# 3  0 days 08:32:11.146000    RIC            3 0 days 00:01:32.599000
# 4  0 days 08:53:38.713000    GAS           10 0 days 00:01:32.805000
# 5  0 days 08:17:47.870000    STR           18 0 days 00:01:33.007000
# 6  0 days 01:58:22.596000    LEC           16 0 days 00:01:33.247000
# 7  0 days 01:40:27.098000    ALO           14 0 days 00:01:33.385000
# 8  0 days 03:51:25.440000    PIA           81 0 days 00:01:33.658000
# 9  0 days 06:49:17.892000    ZHO           24 0 days 00:01:33.871000
# 10 0 days 07:32:16.452000    SAR            2 0 days 00:01:33.882000
# 11 0 days 05:59:39.609000    RUS           63 0 days 00:01:34.109000
# 12 0 days 02:49:29.745000    TSU           22 0 days 00:01:34.136000
# 13 0 days 01:16:35.230000    BOT           77 0 days 00:01:34.431000
# 14 0 days 01:14:02.752000    ALB           23 0 days 00:01:34.587000
# 15 0 days 02:42:17.193000    OCO           31 0 days 00:01:34.677000
# 16 0 days 00:22:36.380000    MAG           20 0 days 00:01:35.692000
# 17 0 days 07:35:16.213000    HUL           27 0 days 00:01:35.906000
#
#     LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0       126.0   23.0        NaT       NaT 0 days 00:00:29.066000
# 1        15.0    6.0        NaT       NaT 0 days 00:00:29.514000
# 2        23.0    6.0        NaT       NaT 0 days 00:00:29.501000
# 3        34.0    7.0        NaT       NaT 0 days 00:00:29.778000
# 4        53.0   15.0        NaT       NaT 0 days 00:00:29.705000
# 5        28.0    5.0        NaT       NaT 0 days 00:00:29.667000
# 6        19.0    5.0        NaT       NaT 0 days 00:00:29.795000
# 7        27.0    5.0        NaT       NaT 0 days 00:00:29.680000
# 17 0 days 07:33:40.307000 2024-02-21 14:28:52.066            1       NaN
#
#     Deleted  DeletedReason  FastF1Generated IsAccurate
# 0     False                           False       True
# 1     False                           False       True
# 2     False                           False       True
# 3     False                           False       True
# 4     False                           False       True
# 5     False                           False       True
# 6     False                           False       True
# 7     False                           False       True
# 8     False                           False       True
# 9     False                           False       True
# 10    False                           False       True
# 11    False                           False       True
# 12    False                           False       True
# 13    False                           False       True
# 14    False                           False       True
# 15    False                           False       True
# 16    False                           False       True
# 17    False                           False       True
#
# [18 rows x 31 columns]

# %%
'''Generates the gap to the leader'''

fastest_laps_day1["GapToLead"] = fastest_laps_day1["LapTime"] - fastest_laps_day1["LapTime"][0]
fastest_laps_day2["GapToLead"] = fastest_laps_day2["LapTime"] - fastest_laps_day2["LapTime"][0]

# %%
fig = px.bar(
    data_frame=fastest_laps_day1,
    x=fastest_laps_day1["Driver"],
    y=fastest_laps_day1["GapToLead"],
    template="plotly_dark",
)

fig.show()

# %%
plt.figure(figsize=(14,8), dpi=120, facecolor="black")
plt.yticks(color="white", fontsize=12, fontname="Formula1")
plt.xticks(fontsize=14, color="white", fontname="Formula1")
plt.xlabel("Gap to Leader (Tenths of a Second)", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("black")

ax.set_axisbelow(True)
ax.xaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
ax.invert_yaxis()


plt.barh(fastest_laps_day1.Driver, fastest_laps_day1.GapToLead, color=team_colours_day1,)

lap_time_string = strftimedelta(fastest_lap_day1["LapTime"], "%m:%s.%ms")
plt.suptitle(f"{day1.event["EventName"]} {day1.event.year}, Day 1\n"
             f"Fastest Lap: {lap_time_string} ({fastest_lap_day1["Driver"]})",
             fontsize=18, color="white", fontname="Formula1"
             )

fig = plt.figure()
fig.patch.set_facecolor("black")

# %%
fastest_laps_day2
# Out:
#                      Time Driver DriverNumber                LapTime  \
# 0  0 days 06:51:21.198000    SAI           55 0 days 00:01:29.921000
# 1  0 days 09:02:10.265000    PER           11 0 days 00:01:30.679000
# 2  0 days 08:24:17.410000    HAM           44 0 days 00:01:31.066000
# 3  0 days 06:35:16.519000    NOR            4 0 days 00:01:31.256000
# 4  0 days 08:49:03.092000    RIC            3 0 days 00:01:31.361000
# 5  0 days 01:00:19.669000    LEC           16 0 days 00:01:31.750000
# 6  0 days 06:16:02.579000    STR           18 0 days 00:01:32.029000
# 7  0 days 08:42:26.919000    OCO           31 0 days 00:01:32.061000
# 8  0 days 05:51:06.315000    BOT           77 0 days 00:01:32.227000
# 9  0 days 01:13:24.871000    PIA           81 0 days 00:01:32.328000
# 10 0 days 01:31:58.788000    SAR            2 0 days 00:01:32.578000
# 11 0 days 01:59:24.866000    ALO           14 0 days 00:01:33.053000
# 12 0 days 01:47:42.911000    ZHO           24 0 days 00:01:33.715000
# 13 0 days 00:42:14.819000    GAS           10 0 days 00:01:33.804000
# 14 0 days 04:35:30.930000    MAG           20 0 days 00:01:36.611000
# 15 0 days 02:20:15.613000    HUL           27 0 days 00:01:37.509000
# 16 0 days 02:31:35.777000    TSU           22 0 days 00:01:38.074000
#
#     LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 
# 6  2024-02-22 13:03:00.639           1       NaN    False
# 7  2024-02-22 15:29:24.947           1       NaN    False
# 8  2024-02-22 12:38:04.177           1       NaN    False
# 9  2024-02-22 08:00:22.632           1       NaN    False
# 10 2024-02-22 08:18:56.299           1       NaN    False
# 11 2024-02-22 08:46:21.902           1       NaN    False
# 12 2024-02-22 08:34:39.285           1       NaN    False
# 13 2024-02-22 07:29:11.104           1       NaN    False
# 14 2024-02-22 11:22:24.408           1       NaN    False
# 15 2024-02-22 09:07:08.193           1       NaN    False
# 16 2024-02-22 09:18:27.792           1       NaN    False
#
#     FastF1Generated  IsAccurate              GapToLead
# 0             False        True        0 days 00:00:00
# 1             False        True 0 days 00:00:00.758000
# 2             False        True 0 days 00:00:01.145000
# 3             False        True 0 days 00:00:01.335000
# 4             False        True 0 days 00:00:01.440000
# 5             False        True 0 days 00:00:01.829000
# 6             False        True 0 days 00:00:02.108000
# 7             False        True 0 days 00:00:02.140000
# 8             False        True 0 days 00:00:02.306000
# 9             False        True 0 days 00:00:02.407000
# 10            False        True 0 days 00:00:02.657000
# 11            False        True 0 days 00:00:03.132000
# 12            False        True 0 days 00:00:03.794000
# 13            False        True 0 days 00:00:03.883000
# 14            False        True 0 days 00:00:06.690000
# 15            False        True 0 days 00:00:07.588000
# 16            False        True 0 days 00:00:08.153000
#
# [17 rows x 32 columns]

# %%
plt.figure(figsize=(14,8), dpi=120, facecolor="black")
plt.yticks(color="white", fontsize=12, fontname="Formula1")
plt.xticks(fontsize=12, color="white", fontname="Formula1")
plt.xlabel("Gap to Leader", fontsize=14, color="white", fontname="Formula1")

ax = plt.gca()
ax.patch.set_facecolor("black")

ax.set_axisbelow(True)
ax.xaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
ax.invert_yaxis()


plt.barh(fastest_laps_day2.Driver, fastest_laps_day2.GapToLead, color=team_colours_day2,)

lap_time_string = strftimedelta(fastest_lap_day2["LapTime"], "%m:%s.%ms")
plt.suptitle(f"{day2.event["EventName"]} {day2.event.year}, Day 2\n"
             f"Fastest Lap: {lap_time_string} ({fastest_lap_day2["Driver"]})",
             fontsize=18, color="white", fontname="Formula1"
             )

fig = plt.figure()
fig.patch.set_facecolor("black")

# %%
fastest_laps_day2
# Out:
#                      Time Driver DriverNumber                LapTime  \
# 0  0 days 06:51:21.198000    SAI           55 0 days 00:01:29.921000
# 1  0 days 09:02:10.265000    PER           11 0 days 00:01:30.679000
# 2  0 days 08:24:17.410000    HAM           44 0 days 00:01:31.066000
# 3  0 days 06:35:16.519000    NOR            4 0 days 00:01:31.256000
# 4  0 days 08:49:03.092000    RIC            3 0 days 00:01:31.361000
# 5  0 days 01:00:19.669000    LEC           16 0 days 00:01:31.750000
# 6  0 days 06:16:02.579000    STR           18 0 days 00:01:32.029000
# 7  0 days 08:42:26.919000    OCO           31 0 days 00:01:32.061000
# 8  0 days 05:51:06.315000    BOT           77 0 days 00:01:32.227000
# 9  0 days 01:13:24.871000    PIA           81 0 days 00:01:32.328000
#               LapStartDate TrackStatus  Position  Deleted  DeletedReason  \
# 0  2024-02-22 13:38:21.366           1       NaN    False
# 1  2024-02-22 15:49:09.675           1       NaN    False
# 2  2024-02-22 15:11:16.433           1       NaN    False
# 3  2024-02-22 13:22:15.352           1       NaN    False
# 4  2024-02-22 15:36:01.820           1       NaN    False
# 5  2024-02-22 07:47:18.008           1       NaN    False
# 6  2024-02-22 13:03:00.639           1       NaN    False
# 7  2024-02-22 15:29:24.947           1       NaN    False
# 8  2024-02-22 12:38:04.177           1       NaN    False
# 9  2024-02-22 08:00:22.632           1       NaN    False
# 10 2024-02-22 08:18:56.299           1       NaN    False
# 11 2024-02-22 08:46:21.902           1       NaN    False
# 12 2024-02-22 08:34:39.285           1       NaN    False
# 13 2024-02-22 07:29:11.104           1       NaN    False
# 14 2024-02-22 11:22:24.408           1       NaN    False
# 15 2024-02-22 09:07:08.193           1       NaN    False
# 16 2024-02-22 09:18:27.792           1       NaN    False
#
#     FastF1Generated  IsAccurate              GapToLead
# 0             False        True        0 days 00:00:00
# 1             False        True 0 days 00:00:00.758000
# 2             False        True 0 days 00:00:01.145000
# 3             False        True 0 days 00:00:01.335000
# 4             False        True 0 days 00:00:01.440000
# 5             False        True 0 days 00:00:01.829000
# 6             False        True 0 days 00:00:02.108000
# 7             False        True 0 days 00:00:02.140000
# 8             False        True 0 days 00:00:02.306000
# 9             False        True 0 days 00:00:02.407000
# 10            False        True 0 days 00:00:02.657000
# 11            False        True 0 days 00:00:03.132000
# 12            False        True 0 days 00:00:03.794000
# 13            False        True 0 days 00:00:03.883000
# 14            False        True 0 days 00:00:06.690000
# 15            False        True 0 days 00:00:07.588000
# 16            False        True 0 days 00:00:08.153000
#
# [17 rows x 32 columns]

# %%
sai_lap = day2.laps.pick_driver("SAI").pick_fastest()
nor_lap = day2.laps.pick_driver("NOR").pick_fastest()
per_lap = day2.laps.pick_driver("PER").pick_fastest()
ham_lap = day2.laps.pick_driver("HAM").pick_fastest()

sai_tel = sai_lap.get_car_data().add_distance()
nor_tel = nor_lap.get_car_data().add_distance()
per_tel = per_lap.get_car_data().add_distance()
ham_tel = ham_lap.get_car_data().add_distance()

# %%
lap_diff = nor_lap["LapTime"] - per_lap["LapTime"]
lap_diff
# Out:
# Timedelta('0 days 00:00:00.577000')

# %%
fer_colour = team_colours["Ferrari"]
mcl_colour = team_colours["McLaren"]
rbr_colour = team_colours["Red Bull Racing"]

fig, ax = plt.subplots(figsize=(14,8), dpi=120)

ax.plot(sai_tel["Distance"], sai_tel["Speed"], color=fer_colour, label="SAI")
ax.plot(per_tel["Distance"], per_tel["Speed"], color=rbr_colour, label="PER")

ax.set_xlabel("Distance in metres", fontname="Formula1", fontsize=14)
ax.set_ylabel("Speed in km/h", fontname="Formula1", fontsize=14)

ax.patch.set_facecolor("black")
l = ax.legend(facecolor="black", labelcolor="white")
plt.setp(l.texts, family="Formula1", size=12)


fig.patch.set_facecolor("black")

lap_time_string = strftimedelta(lap_diff, "%s.%ms")
plt.suptitle(f"Fastest Lap Comparison\n{day2.event["EventName"]} {day2.event.year}",
             fontsize=16, fontname="Formula1", color="white", fontweight="bold")

plt.show()

# %%
sai_laps = day2_laps[day2_laps["Driver"] == "SAI"]

# %%
plt.figure(figsize=(14,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")

ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.001 , top=0.0012)

plt.scatter(
    sai_laps.LapNumber, sai_laps.LapTime,
    color=team_colours["Ferrari"]
)

# %%
all_laps_by_team = dict()

for team in teams:

    team_day1 = day1_laps[day1_laps["Team"] == team]
    team_day1["Day"] = "Day 1"

    team_day2 = day2_laps[day2_laps["Team"] == team]
    team_day2["Day"] = "Day 2"

    team_day3 = day3_laps[day3_laps["Team"] == team]
    team_day3["Day"] = "Day 3"

    team_laps_total = pd.concat([team_day1, team_day2, team_day3], ignore_index=True)

    all_laps_by_team[team] = team_laps_total.reset_index()
# Out:
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\maxvo\AppData\Local\Temp\ipykernel_27820\2888065089.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
current_team = "Ferrari"
current_team_data = all_laps_by_team[current_team]
current_team_colour = team_colours[current_team]

plt.figure(figsize=(16,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")





ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103 , top=0.0012)
plt.xlim(0, 344)

plt.text(25.5, 0.00119, "LEC", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=51, label = 'axvline - full height', color="grey")
plt.text(78.5, 0.00119, "SAI", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=106, label = 'axvline - full height', color="grey")
plt.text(126, 0.00119, "LEC", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=145, label = 'axvline - full height', color="grey")
plt.text(183.5, 0.00119, "SAI", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=221, label = 'axvline - full height', color="grey")
plt.text(251, 0.00119, "SAI", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=281, label = 'axvline - full height', color="grey")
plt.text(312.5, 0.00119, "LEC", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)

plt.scatter(
    current_team_data.index, current_team_data.LapTime, s=12,
    color=current_team_colour
)

# %%
current_team = "Red Bull Racing"
current_team_data = all_laps_by_team[current_team]
current_team_colour = team_colours[current_team]


plt.figure(figsize=(16,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103 , top=0.0012)
plt.xlim(0, 332)

plt.text(63, 0.00119, "VER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=125.5, label = 'axvline - full height', color="grey")

plt.text(180, 0.00119, "PER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=234, label = 'axvline - full height', color="grey")
plt.text(262.5, 0.00119, "VER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=291, label = 'axvline - full height', color="grey")
plt.text(311.5, 0.00119, "PER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)


plt.scatter(
    current_team_data.index, current_team_data.LapTime, s=12,
    color=current_team_colour
)

# %%
current_team = "Red Bull Racing"
current_team_data = all_laps_by_team[current_team]
current_team_colour = team_colours[current_team]

plt.figure(figsize=(16,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103 , top=0.0012)
plt.xlim(0, 332)

plt.text(63, 0.00119, "VER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=125.5, label = 'axvline - full height', color="grey")

plt.text(180, 0.00119, "PER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=234, label = 'axvline - full height', color="grey")
plt.text(262.5, 0.00119, "VER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=291, label = 'axvline - full height', color="grey")
plt.text(311.5, 0.00119, "PER", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)

medium_tyres = current_team_data[current_team_data["Compound"] == "MEDIUM"]
hard_tyres = current_team_data[current_team_data["Compound"] == "HARD"]


ax.scatter(
    medium_tyres.index, medium_tyres.LapTime, s=12,
    color=tyre_colours["medium"],
)
ax.scatter(
    hard_tyres.index, hard_tyres.LapTime, s=12,
    color=tyre_colours["hard"],
)

# %%
current_team = "Ferrari"
current_team_data = all_laps_by_team[current_team]

plt.figure(figsize=(16,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103 , top=0.0012)
plt.xlim(0, 344)

plt.text(25.5, 0.00119, "LEC", fontsize=16, fontname="Formula1", horizontalalignment='center', color=team_colours[current_team])
plt.axvline(x=51, label = 'axvline - full height', color="grey")
plt.text(78.5, 0.00119, "SAI", fontsize=16, fontname="Formula1", horizontalalignment='center', color=team_colours[current_team])
plt.axvline(x=106, label = 'axvline - full height', color="grey")
plt.text(126, 0.00119, "LEC", fontsize=16, fontname="Formula1", horizontalalignment='center', color=team_colours[current_team])
plt.axvline(x=145, label = 'axvline - full height', color="grey")
plt.text(183.5, 0.00119, "SAI", fontsize=16, fontname="Formula1", horizontalalignment='center', color=team_colours[current_team])
plt.axvline(x=221, label = 'axvline - full height', color="grey")
plt.text(251, 0.00119, "SAI", fontsize=16, fontname="Formula1", horizontalalignment='center', color=team_colours[current_team])
plt.axvline(x=281, label = 'axvline - full height', color="grey")
plt.text(312.5, 0.00119, "LEC", fontsize=16, fontname="Formula1", horizontalalignment='center', color=team_colours[current_team])



medium_tyres = current_team_data[current_team_data["Compound"] == "MEDIUM"]
hard_tyres = current_team_data[current_team_data["Compound"] == "HARD"]


ax.scatter(
    medium_tyres.index, medium_tyres.LapTime, s=12,
    color=tyre_colours["medium"],
)
ax.scatter(
    hard_tyres.index, hard_tyres.LapTime, s=12,
    color=tyre_colours["hard"],
)

# %%
current_team = "Mercedes"
current_team_data = all_laps_by_team[current_team]
current_team_colour = team_colours[current_team]

plt.figure(figsize=(16,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103 , top=0.0012)
plt.xlim(0, 306)

plt.text(52, 0.00119, "RUS", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=104, label = 'axvline - full height', color="grey")

plt.text(157, 0.00119, "HAM", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=210, label = 'axvline - full height', color="grey")

plt.text(230, 0.00119, "HAM", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=250, label = 'axvline - full height', color="grey")
plt.text(278, 0.00119, "RUS", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)



medium_tyres = current_team_data[current_team_data["Compound"] == "MEDIUM"]
hard_tyres = current_team_data[current_team_data["Compound"] == "HARD"]


ax.scatter(
    medium_tyres.index, medium_tyres.LapTime, s=12,
    color=tyre_colours["medium"],
)
ax.scatter(
    hard_tyres.index, hard_tyres.LapTime, s=12,
    color=tyre_colours["hard"],
)





# 104 day 1

# %%
current_team = "McLaren"
current_team_data = all_laps_by_team[current_team]
current_team_colour = team_colours[current_team]

plt.figure(figsize=(16,8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103 , top=0.0012)
plt.xlim(0, 263)

plt.text(31.5, 0.00119, "NOR", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=63, label = 'axvline - full height', color="grey")
plt.text(84, 0.00119, "PIA", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=105, label = 'axvline - full height', color="grey")

plt.text(123.5, 0.00119, "NOR", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=142, label = 'axvline - full height', color="grey")
plt.text(155, 0.00119, "PIA", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=168, label = 'axvline - full height', color="grey")


plt.text(175.5, 0.00119, "NOR", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)
plt.axvline(x=183, label = 'axvline - full height', color="grey")
plt.text(223, 0.00119, "PIA", fontsize=16, fontname="Formula1", horizontalalignment='center', color=current_team_colour)



medium_tyres = current_team_data[current_team_data["Compound"] == "MEDIUM"]
hard_tyres = current_team_data[current_team_data["Compound"] == "HARD"]


ax.scatter(
    medium_tyres.index, medium_tyres.LapTime, s=12,
    color=tyre_colours["medium"],
)
ax.scatter(
    hard_tyres.index, hard_tyres.LapTime, s=12,
    color=tyre_colours["hard"],
)

# %%
day = all_laps_by_team["McLaren"][all_laps_by_team["McLaren"]["Day"] == "Day 3"]

day[day["Driver"] == "PIA"]
# Out:
#      index                   Time Driver DriverNumber                LapTime  \
# 184    184 0 days 05:05:05.861000    PIA           81 0 days 00:01:41.072000
# 185    185 0 days 05:06:45.428000    PIA           81 0 days 00:01:39.567000
# 186    186 0 days 05:08:24.482000    PIA           81 0 days 00:01:39.054000
# 187    187 0 days 05:10:03.556000    PIA           81 0 days 00:01:39.074000
# 188    188 0 days 05:11:42.805000    PIA           81 0 days 00:01:39.249000
# ..     ...                    ...    ...          ...                    ...
# 259    259 0 days 08:58:08.013000    PIA           81 0 days 00:01:35.759000
# 260    260 0 days 08:59:44.049000    PIA           81 0 days 00:01:36.036000
# 261    261 0 days 09:01:20.274000    PIA           81 0 days 00:01:36.225000
# 262    262 0 days 09:02:56.854000    PIA           81 0 days 00:01:36.580000
# 263    263 0 days 09:04:33.612000    PIA           81 0 days 00:01:36.758000
#
#      LapNumber  Stint PitOutTime PitInTime            Sector1Time  ...  \
# 184        2.0    1.0        NaT       NaT 0 days 00:00:32.297000  ...
# 185        3.0    1.0        NaT       NaT 0 days 00:00:31.825000  ...
# 186        4.0    1.0        NaT       NaT 0 days 00:00:31.666000  ...
# 187        5.0    1.0        NaT       NaT 0 days 00:00:31.702000  ...
# 188        6.0    1.0        NaT       NaT 0 days 00:00:31.653000  ...
# ..         ...    ...        ...       ...                    ...  ...
# 259       86.0   12.0        NaT       NaT 0 days 00:00:30.719000  ...
# 260       87.0   12.0        NaT       NaT 0 days 00:00:30.806000  ...
# 261       88.0   12.0        NaT       NaT 0 days 00:00:30.771000  ...
# 262       89.0   12.0        NaT       NaT 0 days 00:00:30.918000  ...
# 263       90.0   12.0        NaT       NaT 0 days 00:00:31.059000  ...
#
#         Team           LapStartTime            LapStartDate TrackStatus  \
# 184  McLaren 0 days 05:03:24.789000 2024-02-23 11:53:34.398           1
# 185  McLaren 0 days 05:05:05.861000 2024-02-23 11:55:15.470           1
# 186  McLaren 0 days 05:06:45.428000 2024-02-23 11:56:55.037           1
# 187  McLaren 0 days 05:08:24.482000 2024-02-23 11:58:34.091           1
# 188  McLaren 0 days 05:10:03.556000 2024-02-23 12:00:13.165           1
# ..       ...                    ...                     ...         ...
# 259  McLaren 0 days 08:56:32.254000 2024-02-23 15:46:41.863           1
# 260  McLaren 0 days 08:58:08.013000 2024-02-23 15:48:17.622           1
# 261  McLaren 0 days 08:59:44.049000 2024-02-23 15:49:53.658           1
# 262  McLaren 0 days 09:01:20.274000 2024-02-23 15:51:29.883           1
# 263  McLaren 0 days 09:02:56.854000 2024-02-23 15:53:06.463           1
#
#     Position  Deleted  DeletedReason  FastF1Generated  IsAccurate    Day
# 184      NaN    False                           False        True  Day 3
# 185      NaN    False                           False        True  Day 3
# 186      NaN    False                           False        True  Day 3
# 187      NaN    False                           False        True  Day 3
# 188      NaN    False                           False        True  Day 3
# ..       ...      ...            ...              ...         ...    ...
# 259      NaN    False                           False        True  Day 3
# 260      NaN    False                           False        True  Day 3
# 261      NaN    False                           False        True  Day 3
# 262      NaN    False                           False        True  Day 3
# 263      NaN    False                           False        True  Day 3
#
# [80 rows x 33 columns]

# %%
team_long_runs = dict()
team_long_runs_filtered = dict()

for team in all_laps_by_team:
    team_data = all_laps_by_team[team]

    team_data["BoxLap"] = 0

    team_data.loc[(team_data["PitOutTime"].notnull()) | (team_data["PitInTime"].notnull()), "BoxLap"] = 1
    
    team_data["StintLength"] = team_data.groupby(["Day", "Stint"])["Stint"].transform("size")
    team_data["StintLength"] = team_data["StintLength"] - 2

    long_runs = team_data[(team_data["StintLength"] > 5) & (team_data["BoxLap"] == 0)].copy()

    team_long_runs[team] = long_runs

    # dropping stints with a high variance 
    stint_std = long_runs.groupby("Stint")["LapTime"].std().reset_index()
    long_runs_with_std = pd.merge(long_runs, stint_std, on="Stint", suffixes=("", "_std"))

    threshold = pd.Timedelta("0 days 00:00:01")  # threshold is the stnadard deviation of LapTime for each stint

    high_variance_stints = long_runs_with_std[long_runs_with_std['LapTime_std'] > threshold]['Stint']

    long_runs_filtered = long_runs[~long_runs["Stint"].isin(high_variance_stints)].copy()

    long_runs_filtered.reset_index(drop=True, inplace=True)

    team_long_runs_filtered[team] = long_runs_filtered

# %%
all_laps_by_team["McLaren"].dtypes
# Out:
# index                           int64
# Time                  timedelta64[ns]
# Driver                         object
# DriverNumber                   object
# LapTime               timedelta64[ns]
# LapNumber                     float64
# Stint                         float64
# PitOutTime            timedelta64[ns]
# PitInTime             timedelta64[ns]
# Sector1Time           timedelta64[ns]
# Sector2Time           timedelta64[ns]
# Sector3Time           timedelta64[ns]
# Sector1SessionTime    timedelta64[ns]
# Sector2SessionTime    timedelta64[ns]
# Sector3SessionTime    timedelta64[ns]
# SpeedI1                       float64
# SpeedI2                       float64
# SpeedFL                       float64
# SpeedST                       float64
# IsPersonalBest                   bool
# Compound                       object
# TyreLife                      float64
# FreshTyre                        bool
# Team                           object
# LapStartTime          timedelta64[ns]
# LapStartDate           datetime64[ns]
# TrackStatus                    object
# Position                      float64
# Deleted                          bool
# DeletedReason                  object
# FastF1Generated                  bool
# IsAccurate                       bool
# Day                            object
# BoxLap                          int64
# StintLength                     int64
# dtype: object

# %%
team_long_runs["McLaren"]
# Out:
#      index                   Time Driver DriverNumber                LapTime  \
# 19      19 0 days 07:27:48.473000    NOR            4 0 days 00:01:36.472000
# 20      20 0 days 07:29:25.300000    NOR            4 0 days 00:01:36.827000
# 21      21 0 days 07:31:02.231000    NOR            4 0 days 00:01:36.931000
# 22      22 0 days 07:32:39.090000    NOR            4 0 days 00:01:36.859000
# 23      23 0 days 07:34:16.542000    NOR            4 0 days 00:01:37.452000
# ..     ...                    ...    ...          ...                    ...
# 259    259 0 days 08:58:08.013000    PIA           81 0 days 00:01:35.759000
# 260    260 0 days 08:59:44.049000    PIA           81 0 days 00:01:36.036000
# 261    261 0 days 09:01:20.274000    PIA           81 0 days 00:01:36.225000
# 262    262 0 days 09:02:56.854000    PIA           81 0 days 00:01:36.580000
# 263    263 0 days 09:04:33.612000    PIA           81 0 days 00:01:36.758000
#
#      LapNumber  Stint PitOutTime PitInTime            Sector1Time  ...  \
# 19        25.0    8.0        NaT       NaT 0 days 00:00:30.903000  ...
# 20        26.0    8.0        NaT       NaT 0 days 00:00:30.993000  ...
# 21        27.0    8.0        NaT       NaT 0 days 00:00:31.029000  ...
# 22        28.0    8.0        NaT       NaT 0 days 00:00:30.974000  ...
# 23        29.0    8.0        NaT       NaT 0 days 00:00:30.973000  ...
# ..         ...    ...        ...       ...                    ...  ...
# 259       86.0   12.0        NaT       NaT 0 days 00:00:30.719000  ...
# 260       87.0   12.0        NaT       NaT 0 days 00:00:30.806000  ...
# 261       88.0   12.0        NaT       NaT 0 days 00:00:30.771000  ...
# 262       89.0   12.0        NaT       NaT 0 days 00:00:30.918000  ...
# 263       90.0   12.0        NaT       NaT 0 days 00:00:31.059000  ...
#
#                LapStartDate TrackStatus Position Deleted DeletedReason  \
# 19  2024-02-21 14:21:23.760           1      NaN   False
# 20  2024-02-21 14:23:00.232           1      NaN   False
# 21  2024-02-21 14:24:37.059           1      NaN   False
# 22  2024-02-21 14:26:13.990           1      NaN   False
# 23  2024-02-21 14:27:50.849           1      NaN   False
# ..                      ...         ...      ...     ...           ...
# 259 2024-02-23 15:46:41.863           1      NaN   False
# 260 2024-02-23 15:48:17.622           1      NaN   False
# 261 2024-02-23 15:49:53.658           1      NaN   False
# 262 2024-02-23 15:51:29.883           1      NaN   False
# 263 2024-02-23 15:53:06.463           1      NaN   False
#
#      FastF1Generated  IsAccurate    Day  BoxLap  StintLength
# 19             False        True  Day 1       0           19
# 20             False        True  Day 1       0           19
# 21             False        True  Day 1       0           19
# 22             False        True  Day 1       0           19
# 23             False        True  Day 1       0           19
# ..               ...         ...    ...     ...          ...
# 259            False        True  Day 3       0           11
# 260            False        True  Day 3       0           11
# 261            False        True  Day 3       0           11
# 262            False        True  Day 3       0           11
# 263            False        True  Day 3       0           11
#
# [185 rows x 35 columns]

# %%
team_long_runs_filtered["McLaren"]
# Out:
#     index                   Time Driver DriverNumber                LapTime  \
# 0      33 0 days 08:00:17.776000    NOR            4 0 days 00:01:37.956000
# 1      34 0 days 08:01:55.318000    NOR            4 0 days 00:01:37.542000
# 2      35 0 days 08:03:32.957000    NOR            4 0 days 00:01:37.639000
# 3      36 0 days 08:05:10.386000    NOR            4 0 days 00:01:37.429000
# 4      37 0 days 08:06:47.900000    NOR            4 0 days 00:01:37.514000
# ..    ...                    ...    ...          ...                    ...
# 62    244 0 days 08:33:17.841000    PIA           81 0 days 00:01:37.555000
# 63    245 0 days 08:34:55.064000    PIA           81 0 days 00:01:37.223000
# 64    246 0 days 08:36:32.147000    PIA           81 0 days 00:01:37.083000
# 65    247 0 days 08:38:09.478000    PIA           81 0 days 00:01:37.331000
# 66    248 0 days 08:39:46.543000    PIA           81 0 days 00:01:37.065000
#
#     LapNumber  Stint PitOutTime PitInTime            Sector1Time  ...  \
# 0        40.0    9.0        NaT       NaT 0 days 00:00:31.450000  ...
# 1        41.0    9.0        NaT       NaT 0 days 00:00:31.139000  ...
# 2        42.0    9.0        NaT       NaT 0 days 00:00:31.165000  ...
# 3        43.0    9.0        NaT       NaT 0 days 00:00:31.110000  ...
# 4        44.0    9.0        NaT       NaT 0 days 00:00:31.192000  ...
# ..        ...    ...        ...       ...                    ...  ...
# 62       71.0   10.0        NaT       NaT 0 days 00:00:31.132000  ...
# 63       72.0   10.0        NaT       NaT 0 days 00:00:31.016000  ...
# 64       73.0   10.0        NaT       NaT 0 days 00:00:31.071000  ...
# 65       74.0   10.0        NaT       NaT 0 days 00:00:31.218000  ...
# 66       75.0   10.0        NaT       NaT 0 days 00:00:31.093000  ...
#
#               LapStartDate TrackStatus Position Deleted DeletedReason  \
# 0  2024-02-21 14:53:51.579           1      NaN   False
# 1  2024-02-21 14:55:29.535           1      NaN   False
# 2  2024-02-21 14:57:07.077           1      NaN   False
# 3  2024-02-21 14:58:44.716           1      NaN   False
# 4  2024-02-21 15:00:22.145           1      NaN   False
# ..                     ...         ...      ...     ...           ...
# 62 2024-02-23 15:21:49.895           1      NaN   False
# 63 2024-02-23 15:23:27.450           1      NaN   False
# 64 2024-02-23 15:25:04.673           1      NaN   False
# 65 2024-02-23 15:26:41.756           1      NaN   False
# 66 2024-02-23 15:28:19.087           1      NaN   False
#
#     FastF1Generated  IsAccurate    Day  BoxLap  StintLength
# 0             False        True  Day 1       0           11
# 1             False        True  Day 1       0           11
# 2             False        True  Day 1       0           11
# 3             False        True  Day 1       0           11
# 4             False        True  Day 1       0           11
# ..              ...         ...    ...     ...          ...
# 62            False        True  Day 3       0           21
# 63            False        True  Day 3       0           21
# 64            False        True  Day 3       0           21
# 65            False        True  Day 3       0           21
# 66            False        True  Day 3       0           21
#
# [67 rows x 35 columns]

# %%
for team in all_laps_by_team:
    team_data = all_laps_by_team[team]
    lap_count = team_data["LapNumber"].count()
    print(f"{team}: {lap_count}")
# Out:
# Ferrari: 344
# Red Bull Racing: 332
# Mercedes: 306
# McLaren: 264
# RB: 315
# Aston Martin: 314
# Kick Sauber: 333
# Haas F1 Team: 398
# Williams: 247
# Alpine: 257

# %%
all_laps_by_team["McLaren"][all_laps_by_team["McLaren"]["PitInTime"].notnull()]
# Out:
#      index                   Time Driver DriverNumber                LapTime  \
# 2        2 0 days 06:05:50.461000    NOR            4 0 days 00:01:38.190000
# 3        3 0 days 06:08:05.759000    NOR            4 0 days 00:02:15.298000
# 4        4 0 days 06:10:13.675000    NOR            4 0 days 00:02:07.916000
# 171 0 days 00:00:30.089000  ... 2024-02-23 07:06:31.585           1      NaN
# 178 0 days 00:00:30.873000  ... 2024-02-23 08:55:57.448           1      NaN
# 180 0 days 00:00:40.349000  ... 2024-02-23 09:17:22.006           1      NaN
# 183 0 days 00:00:31.516000  ... 2024-02-23 09:22:47.958           1      NaN
# 200 0 days 00:00:31.844000  ... 2024-02-23 12:20:08.829           1      NaN
# 202 0 days 00:00:43.195000  ... 2024-02-23 13:19:50.484           1      NaN
# 204 0 days 00:00:30.397000  ... 2024-02-23 13:32:53.733           1      NaN
# 207 0 days 00:00:29.554000  ... 2024-02-23 13:48:54.486           1      NaN
# 209 0 days 00:00:35.922000  ... 2024-02-23 13:59:22.841           1      NaN
# 211 0 days 00:00:35.061000  ... 2024-02-23 14:08:38.027           1      NaN
# 226 0 days 00:00:31.555000  ... 2024-02-23 14:52:07.041           1      NaN
# 249 0 days 00:00:31.255000  ... 2024-02-23 15:29:56.152           2      NaN
# 250 0 days 00:00:52.435000  ... 2024-02-23 15:31:35.961           1      NaN
#
#     Deleted DeletedReason  FastF1Generated  IsAccurate    Day  BoxLap  \
# 2     False                          False       False  Day 1       1
# 3     False                          False       False  Day 1       1
# 4     False                          False       False  Day 1       1
# 5     False                          False       False  Day 1       1
# 10    False                          False       False  Day 1       1
# 12    False                          False       False  Day 1       1
# 18    False                          False       False  Day 1       1
# 32    False                          False       False  Day 1       1
# 43    False                          False       False  Day 1       1
# 54    False                          False       False  Day 1       1
# 64    False                          False       False  Day 1       1
# 65    False                          False       False  Day 1       1
# 66    False                          False       False  Day 1       1
# 67    False                          False       False  Day 1       1
# 74    False                          False       False  Day 1       1
# 76    False                          False       False  Day 1       1
# 78    False                          False       False  Day 1       1
# 79    False                          False       False  Day 1       1
# 87    False                          False       False  Day 1       1
# 95    False                          False       False  Day 1       1
# 105   False                          False       False  Day 1       1
# 108   False                          False       False  Day 2       1
# 111   False                          False       False  Day 2       1
# 112   False                          False       False  Day 2       1
# 113   False                          False       False  Day 2       1
# 115   False                          False       False  Day 2       1
# 117   False                          False       False  Day 2       1
# 119   False                          False       False  Day 2       1
# 121   False                          False       False  Day 2       1
# 129   False                          False       False  Day 2       1
# 143   False                          False       False  Day 2       1
# 145   False                          False       False  Day 2       1
# 147   False                          False       False  Day 2       1
# 158   False                          False       False  Day 2       1
# 171   False                          False       False  Day 3       1
# 178   False                          False       False  Day 3       1
# 180   False                          False       False  Day 3       1
# 183   False                          False       False  Day 3       1
# 200   False                          False       False  Day 3       1
# 202   False                          False       False  Day 3       1
# 204   False                          False       False  Day 3       1
# 207   False                          False       False  Day 3       1
# 209   False                          False       False  Day 3       1
# 211   False                          False       False  Day 3       1
# 226   False                          False       False  Day 3       1
# 249   False                          False       False  Day 3       1
# 250   False                          False       False  Day 3       1
#
#      StintLength
# 2              1
# 3              0
# 4             -1
# 5              0
# 10             3
# 12             1
# 18             5
# 32            19
# 43            11
# 54            11
# 64             0
# 65             0
# 66             1
# 67             5
# 74            19
# 76            11
# 78            11
# 79             8
# 87             6
# 95             6
# 105            8
# 108            1
# 111            1
# 112            0
# 113            1
# 115           10
# 117            0
# 119            0
# 121            0
# 129            6
# 143            0
# 145            0
# 147            1
# 158            9
# 171           18
# 178            6
# 180            2
# 183            4
# 200           18
# 202            6
# 204            2
# 207            4
# 209            0
# 211            0
# 226           13
# 249           21
# 250           -1
#
# [47 rows x 35 columns]

# %%
team_stint_data = dict()

for team in all_laps_by_team:
    laps = all_laps_by_team[team]

    laps["GlobalStint"] = laps["Stint"]

    day1_laps = laps[laps["Day"] == "Day 1"]
    max_stint_day1 = day1_laps["Stint"].max()
    laps.loc[laps["Day"] == "Day 2", "GlobalStint"] += max_stint_day1

    day2_laps = laps[laps["Day"] == "Day 2"]
    max_stint_day2 = day2_laps["GlobalStint"].max()
    laps.loc[laps["Day"] == "Day 3", "GlobalStint"] += max_stint_day2


    laps = laps[laps["LapTime"] <= pd.Timedelta(minutes=2)]

    filtered_df = laps[laps["PitInTime"].isna() & laps["PitOutTime"].isna()]
    stint_counts = filtered_df["GlobalStint"].value_counts()
    print(stint_counts)
    valid_stints = stint_counts.index[stint_counts > 5]

    filtered_df = filtered_df[filtered_df["GlobalStint"].isin(valid_stints)]
    
    result = filtered_df.groupby('GlobalStint').agg(
        {'LapTime': ['mean', 'std'], 'GlobalStint': 'size'})
    team_stint_data[team] = result
# Out:
# GlobalStint
# 24.0    35
# 32.0    27
# 33.0    26
# 23.0    23
# 22.0    16
# 34.0    13
# 10.0    11
# 9.0     10
# 31.0     9
# 8.0      9
# 11.0     9
# 12.0     9
# 35.0     8
# 13.0     8
# 1.0      6
# 3.0      4
# 14.0     4
# 16.0     3
# 28.0     3
# 4.0      3
# 6.0      3
# 7.0      3
# 17.0     3
# 5.0      2
# 30.0     2
# 29.0     2
# 26.0     2
# 27.0     2
# 25.0     2
# 15.0     2
# 20.0     2
# 19.0     2
# 2.0      2
# 18.0     2
# 21.0     1
# Name: count, dtype: int64
# GlobalStint
# 37.0    21
# 36.0    18
# 56.0    16
# 55.0    16
# 54.0    16
# 35.0    13
# 58.0    10
# 57.0    10
# 18.0     7
# 22.0     7
# 16.0     7
# 14.0     7
# 11.0     7
# 24.0     7
# 9.0      7
# 20.0     7
# 46.0     6
# 44.0     6
# 41.0     6
# 50.0     4
# 52.0     3
# 51.0     3
# 25.0     2
# 1.0      2
# 23.0     2
# 21.0     2
# 19.0     2
# 17.0     2
# 15.0     2
# 53.0     2
# 8.0      2
# 45.0     2
# 48.0     1
# 47.0     1
# 26.0     1
# 43.0     1
# 42.0     1
# 40.0     1
# 39.0     1
# 33.0     1
# 2.0      1
# 13.0     1
# 12.0     1
# 10.0     1
# 7.0      1
# 6.0      1
# 5.0      1
# 4.0      1
# 3.0      1
# 59.0     1
# Name: count, dtype: int64
# GlobalStint
# 17.0    18
# 15.0    17
# 16.0    15
# 31.0    14
# 32.0    14
# 26.0     9
# 28.0     9
# 30.0     9
# 22.0     9
# 7.0      9
# 42.0     8
# 44.0     8
# 40.0     7
# 24.0     7
# 43.0     7
# 45.0     7
# 46.0     7
# 41.0     5
# 38.0     4
# 39.0     4
# 1.0      4
# 9.0      4
# 11.0     3
# 3.0      3
# 20.0     3
# 18.0     3
# 4.0      3
# 5.0      3
# 12.0     3
# 10.0     3
# 36.0     2
# 8.0      1
# 49.0     1
# 48.0     1
# 47.0     1
# 37.0     1
# 6.0      1
# 23.0     1
# 25.0     1
# 35.0     1
# 33.0     1
# 19.0     1
# 29.0     1
# 21.0     1
# 27.0     1
# 2.0      1
# 50.0     1
# Name: count, dtype: int64
# GlobalStint
# 38.0    21
# 29.0    17
# 8.0     16
# 37.0    14
# 28.0    13
# 40.0    12
# 9.0     11
# 22.0    11
# 10.0    11
# 21.0    10
# 14.0     9
# 11.0     8
# 12.0     7
# 13.0     7
# 27.0     7
# 31.0     5
# 7.0      5
# 33.0     2
# 5.0      2
# 32.0     2
# 30.0     1
# 35.0     1
# 34.0     1
# 1.0      1
# 20.0     1
# 19.0     1
# 24.0     1
# 23.0     1
# 16.0     1
# 15.0     1
# 6.0      1
# 25.0     1
# Name: count, dtype: int64
# GlobalStint
# 20.0    28
# 31.0    25
# 30.0    19
# 29.0    18
# 18.0    15
# 21.0    15
# 19.0    14
# 5.0     14
# 14.0     8
# 8.0      6
# 27.0     6
# 26.0     6
# 11.0     6
# 32.0     5
# 4.0      4
# 2.0      3
# 1.0      3
# 6.0      3
# 17.0     2
# 16.0     2
# 34.0     2
# 33.0     2
# 3.0      2
# 7.0      2
# 28.0     2
# 22.0     2
# 15.0     2
# 10.0     1
# 9.0      1
# 25.0     1
# 12.0     1
# 24.0     1
# 23.0     1
# 13.0     1
# 35.0     1
# 36.0     1
# 37.0     1
# Name: count, dtype: int64
# GlobalStint
# 19.0    18
# 18.0    18
# 20.0    18
# 6.0     18
# 34.0    15
# 32.0    15
# 8.0     15
# 9.0     15
# 33.0    14
# 3.0     12
# 2.0     11
# 36.0    10
# 4.0      7
# 5.0      7
# 14.0     5
# 16.0     4
# 7.0      4
# 15.0     4
# 10.0     3
# 30.0     3
# 13.0     3
# 17.0     3
# 21.0     2
# 24.0     2
# 27.0     2
# 28.0     2
# 29.0     2
# 31.0     2
# 12.0     2
# 26.0     2
# 25.0     1
# 35.0     1
# Name: count, dtype: int64
# GlobalStint
# 28.0    23
# 27.0    23
# 20.0    20
# 19.0    17
# 29.0    16
# 6.0     16
# 18.0    15
# 7.0     13
# 4.0     13
# 10.0    12
# 15.0    11
# 13.0    11
# 11.0    11
# 17.0    10
# 22.0    10
# 12.0     9
# 5.0      8
# 3.0      8
# 21.0     5
# 25.0     4
# 2.0      3
# 30.0     2
# 14.0     2
# 9.0      2
# 8.0      2
# 31.0     1
# 32.0     1
# 24.0     1
# 26.0     1
# Name: count, dtype: int64
# GlobalStint
# 21.0    30
# 20.0    24
# 13.0    23
# 22.0    21
# 14.0    19
# 23.0    18
# 11.0    18
# 1.0     18
# 16.0    16
# 15.0    16
# 2.0     16
# 9.0     16
# 5.0     16
# 4.0     15
# 10.0    15
# 8.0     14
# 3.0     13
# 19.0    13
# 12.0    13
# 7.0     11
# 17.0     4
# 18.0     3
# 6.0      2
# Name: count, dtype: int64
# GlobalStint
# 32.0    20
# 52.0    18
# 53.0    16
# 31.0    16
# 30.0    16
# 51.0    15
# 28.0     7
# 4.0      6
# 49.0     6
# 10.0     5
# 7.0      3
# 12.0     2
# 26.0     2
# 33.0     2
# 6.0      2
# 36.0     2
# 9.0      2
# 38.0     1
# 56.0     1
# 37.0     1
# 54.0     1
# 57.0     1
# 55.0     1
# 39.0     1
# 3.0      1
# 25.0     1
# 24.0     1
# 23.0     1
# 19.0     1
# 18.0     1
# 17.0     1
# 16.0     1
# 14.0     1
# 13.0     1
# 5.0      1
# 58.0     1
# Name: count, dtype: int64
# GlobalStint
# 50.0    14
# 49.0    14
# 27.0    11
# 54.0    10
# 53.0    10
# 28.0     9
# 14.0     9
# 11.0     8
# 8.0      7
# 51.0     6
# 7.0      5
# 9.0      5
# 10.0     5
# 31.0     4
# 30.0     4
# 12.0     4
# 29.0     3
# 5.0      3
# 33.0     3
# 6.0      3
# 32.0     2
# 34.0     2
# 35.0     2
# 36.0     2
# 37.0     2
# 47.0     2
# 48.0     2
# 52.0     2
# 4.0      1
# 38.0     1
# 15.0     1
# 3.0      1
# 1.0      1
# Name: count, dtype: int64

# %%
team_stint_data["Red Bull Racing"]
# Out:
#                               LapTime                           GlobalStint
#                                  mean                       std        size
# GlobalStint
# 9.0         0 days 00:01:36.887142857 0 days 00:00:00.299646696           7
# 11.0        0 days 00:01:36.624285714 0 days 00:00:00.128313047           7
# 14.0        0 days 00:01:36.287571428 0 days 00:00:00.193666256           7
# 16.0           0 days 00:01:36.391000 0 days 00:00:00.208041662           7
# 18.0        0 days 00:01:35.611285714 0 days 00:00:00.301323588           7
# 20.0           0 days 00:01:35.430000 0 days 00:00:00.340177404           7
# 22.0        0 days 00:01:35.070857142 0 days 00:00:00.670769316           7
# 24.0        0 days 00:01:34.273857142 0 days 00:00:00.122431516           7
# 35.0        0 days 00:01:38.649461538 0 days 00:00:00.581821652          13
# 36.0           0 days 00:01:38.457500 0 days 00:00:00.458895380          18
# 37.0        0 days 00:01:37.128666666 0 days 00:00:00.213715075          21
# 41.0        0 days 00:01:34.923166666 0 days 00:00:00.189629551           6
# 44.0        0 days 00:01:34.738833333 0 days 00:00:00.734274176           6
# 46.0        0 days 00:01:34.318833333 0 days 00:00:00.438216118           6
# 54.0           0 days 00:01:36.923375 0 days 00:00:01.342376493          16
# 55.0           0 days 00:01:37.434750 0 days 00:00:03.078834097          16
# 56.0        0 days 00:01:36.655437500 0 days 00:00:01.191120367          16
# 57.0           0 days 00:01:38.371400 0 days 00:00:00.229178823          10
# 58.0           0 days 00:01:38.448600 0 days 00:00:00.321598507          10

# %%
for team in team_stint_data:

    df = team_stint_data[team]

    df.columns = ["".join(col).strip() for col in df.columns.values]

# %%
for team in team_stint_data:

    df = team_stint_data[team]

    df['LapTimestd_seconds'] = df['LapTimestd'].dt.total_seconds()

    weighted_std_mean = np.average(
        df['LapTimestd_seconds'], weights=df['GlobalStintsize'])

    weighted_std_mean_timedelta = pd.to_timedelta(weighted_std_mean, unit='s')

    print(f"{team} {weighted_std_mean_timedelta}")
# Out:
# Ferrari 0 days 00:00:01.788283255
# Red Bull Racing 0 days 00:00:00.719794788
# Mercedes 0 days 00:00:01.003370143
# McLaren 0 days 00:00:01.167888519
# RB 0 days 00:00:01.991316432
# Aston Martin 0 days 00:00:01.611214779
# Kick Sauber 0 days 00:00:01.113611526
# Haas F1 Team 0 days 00:00:01.263488322
# Williams 0 days 00:00:00.491436896
# Alpine 0 days 00:00:02.680149440

# %%
team_stint_data["Alpine"]
# Out:
#                           LapTimemean                LapTimestd  \
# GlobalStint
# 8.0         0 days 00:01:37.035142857 0 days 00:00:01.419804614
# 11.0           0 days 00:01:38.290875 0 days 00:00:01.678650685
# 14.0        0 days 00:01:35.494444444 0 days 00:00:01.807035909
# 27.0           0 days 00:01:37.194000 0 days 00:00:02.131892867
# 28.0        0 days 00:01:37.167111111 0 days 00:00:00.923571795
# 49.0        0 days 00:01:38.442142857 0 days 00:00:03.936388463
# 50.0        0 days 00:01:38.318357142 0 days 00:00:03.617084048
# 51.0        0 days 00:01:38.587833333 0 days 00:00:06.946941065
# 53.0           0 days 00:01:38.854300 0 days 00:00:02.116414108
# 54.0           0 days 00:01:38.508400 0 days 00:00:02.266611381
#
#              GlobalStintsize  LapTimestd_seconds
# GlobalStint
# 8.0                        7            1.419805
# 11.0                       8            1.678651
# 14.0                       9            1.807036
# 27.0                      11            2.131893
# 28.0                       9            0.923572
# 49.0                      14            3.936388
# 50.0                      14            3.617084
# 51.0                       6            6.946941
# 53.0                      10            2.116414
# 54.0                      10            2.266611

# %%
current_team = "Alpine"
current_team_data = all_laps_by_team[current_team]
current_team_colour = team_colours[current_team]

plt.figure(figsize=(16, 8), dpi=120, facecolor="#0F0F0F")
plt.yticks(color="white", fontsize=10, fontname="Formula1")
plt.xticks(fontsize=10, color="white", fontname="Formula1")
plt.xlabel("Lap Number", fontsize=14, color="white", fontname="Formula1")
plt.ylabel("Lap Time", fontsize=14, color="white", fontname="Formula1")


ax = plt.gca()
ax.patch.set_facecolor("#000000")

ax.set_axisbelow(True)
ax.yaxis.grid(True, which="major", linestyle="--", color="white", zorder=-1000)
plt.ylim(bottom=0.00103, top=0.0012)
plt.xlim(0, 263)

plt.text(31.5, 0.00119, "NOR", fontsize=16, fontname="Formula1",
         horizontalalignment='center', color=current_team_colour)
plt.axvline(x=63, label='axvline - full height', color="grey")
plt.text(84, 0.00119, "PIA", fontsize=16, fontname="Formula1",
         horizontalalignment='center', color=current_team_colour)
plt.axvline(x=105, label='axvline - full height', color="grey")

plt.text(123.5, 0.00119, "NOR", fontsize=16, fontname="Formula1",
         horizontalalignment='center', color=current_team_colour)
plt.axvline(x=142, label='axvline - full height', color="grey")
plt.text(155, 0.00119, "PIA", fontsize=16, fontname="Formula1",
         horizontalalignment='center', color=current_team_colour)
plt.axvline(x=168, label='axvline - full height', color="grey")


plt.text(175.5, 0.00119, "NOR", fontsize=16, fontname="Formula1",
         horizontalalignment='center', color=current_team_colour)
plt.axvline(x=183, label='axvline - full height', color="grey")
plt.text(223, 0.00119, "PIA", fontsize=16, fontname="Formula1",
         horizontalalignment='center', color=current_team_colour)


medium_tyres = current_team_data[current_team_data["Compound"] == "MEDIUM"]
hard_tyres = current_team_data[current_team_data["Compound"] == "HARD"]


ax.scatter(
    medium_tyres.index, medium_tyres.LapTime, s=12,
    color=tyre_colours["medium"],
)
ax.scatter(
    hard_tyres.index, hard_tyres.LapTime, s=12,
    color=tyre_colours["hard"],
)

# %%
alpine_laps = all_laps_by_team["Alpine"]
alpine_laps[alpine_laps["GlobalStint"] == 7]
# Out:
#     index                   Time Driver DriverNumber                LapTime  \
# 12     12 0 days 06:40:41.640000    GAS           10 0 days 00:01:37.811000
# 13     13 0 days 06:42:43.691000    GAS           10 0 days 00:02:02.051000
# 57     57 0 days 01:22:06.994000    OCO           31 0 days 00:02:03.500000
# 58     58 0 days 01:23:43.638000    OCO           31 0 days 00:01:36.644000
# 59     59 0 days 01:26:10.890000    OCO           31 0 days 00:02:27.252000
# 60     60 0 days 01:27:47.453000    OCO           31 0 days 00:01:36.563000
# 61     61 0 days 01:32:02.911000    OCO           31 0 days 00:01:36.599000
# 62     62 0 days 01:33:41.783000    OCO           31 0 days 00:01:38.872000
# 63     63 0 days 01:35:48.160000    OCO           31 0 days 00:02:06.377000
#
#     LapNumber  Stint PitOutTime              PitInTime            Sector1Time  \
# 12       18.0    7.0        NaT                    NaT 0 days 00:00:31.487000
# 13       19.0    7.0        NaT 0 days 06:42:41.779000 0 days 00:00:38.039000
# 57       16.0    7.0        NaT                    NaT 0 days 00:00:32.558000
# 58       17.0    7.0        NaT                    NaT 0 days 00:00:30.721000
# 59       18.0    7.0        NaT                    NaT 0 days 00:00:48.888000
# 60       19.0    7.0        NaT                    NaT 0 days 00:00:30.711000
# 61       21.0    7.0        NaT                    NaT 0 days 00:00:30.712000
# 62       22.0    7.0        NaT                    NaT 0 days 00:00:31.488000
# 63       23.0    7.0        NaT 0 days 01:35:46.817000 0 days 00:00:38.664000
#
#     ... TrackStatus Position Deleted DeletedReason FastF1Generated  \
# 12  ...           1      NaN   False                         False
# 13  ...           1      NaN   False                         False
# 57  ...           1      NaN   False                         False
# 58  ...           1      NaN   False                         False
# 59  ...           1      NaN   False                         False
# 60  ...           1      NaN   False                         False
# 61  ...           1      NaN   False                         False
# 62  ...           1      NaN   False                         False
# 63  ...           1      NaN   False                         False
#
#     IsAccurate    Day  BoxLap  StintLength  GlobalStint
# 12        True  Day 1       0            7          7.0
# 13       False  Day 1       1            7          7.0
# 57        True  Day 1       0            7          7.0
# 58        True  Day 1       0            7          7.0
# 59        True  Day 1       0            7          7.0
# 60        True  Day 1       0            7          7.0
# 61        True  Day 1       0            7          7.0
# 62        True  Day 1       0            7          7.0
# 63       False  Day 1       1            7          7.0
#
# [9 rows x 36 columns]
