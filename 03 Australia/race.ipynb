# %%
grand_prix = "Australia"

# FORMAT: list of safety cars, start lap to resume lap (i.e. first non-safety car lap)
safety_car_laps = ["17-18", "57-58"]

# %%
import json
import fastf1 as f1

import data.graph_code as f1_graphs

with open("../data/season_info.json") as file:
    season_info = json.loads(file.read())

teams = season_info["teams"]
team_colours = season_info["team_colours"]
tyre_colours = season_info["tyre_colours"]
drivers = season_info["drivers"]
races = season_info["races"]
current_race = races[grand_prix]

data = f1.get_session(year=2024, gp=grand_prix, identifier="R")
data.load()
LAPS = data.laps

initial_data = f1_graphs.initial_setup(data, safety_car_laps)
sc_laps = initial_data["safety_car"] 
all_laps_by_team = initial_data["team_laps"]

circuit_info = data.get_circuit_info()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (402.69 MB) C:\Users\maxvo\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
f1_graphs.race_compare_lap_telemetry(data, "SAI", "PER", lap_number=44)
# Out:
# c:\Users\maxvo\AppData\Local\Programs\Python\Python312\Lib\site-packages\fastf1\utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"

# %%
f1_graphs.race_compare_lap_telemetry(data, "SAI", "PER", 43, dotswap=True)
# Out:
# c:\Users\maxvo\AppData\Local\Programs\Python\Python312\Lib\site-packages\fastf1\utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"

# %%
f1_graphs.race_laps_scatter(data, grand_prix, sc_laps, ["PER", "SAI"])
